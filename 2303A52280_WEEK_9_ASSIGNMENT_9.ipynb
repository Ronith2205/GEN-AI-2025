# %% [markdown]
# <a href="https://colab.research.google.com/github/Ronith2205/GEN-AI-2025/blob/main/2303A52280_WEEK_9_ASSIGNMENT_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adadelta
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
import numpy as np

# Enable eager execution
tf.config.run_functions_eagerly(True)

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Print data shapes for debugging
print(f"x_train shape: {x_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape}")
print(f"y_test shape: {y_test.shape}")

# Normalize the data
x_train, x_test = x_train / 255.0, x_test / 255.0

# One-hot encode the labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Define the ANN model
def build_model(hidden_neurons=[32, 32, 32], activation='relu', epochs=10, batch_size=128):
    model = Sequential()
    model.add(Flatten(input_shape=(28, 28)))

    # Dynamically add hidden layers
    for neurons in hidden_neurons:
        model.add(Dense(neurons, activation=activation))

    model.add(Dense(10, activation='softmax'))  # Output layer

    # Create a new optimizer instance for each model training
    optimizer = Adadelta()
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

    # Train the model
    model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(x_test, y_test), verbose=2)

    # Evaluate the model
    train_loss, train_acc = model.evaluate(x_train, y_train, verbose=0)
    test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)

    return float(train_acc), float(test_acc)

# Initial model evaluation
train_accuracy, test_accuracy = build_model()
print(f"Training Accuracy: {train_accuracy:.4f}")
print(f"Testing Accuracy: {test_accuracy:.4f}")

# Experiment with different architectures
best_accuracy = 0
best_config = None

architectures = [
    ([64, 64, 64], 'relu'),
    ([128, 64, 32], 'relu'),
    ([32, 32, 32], 'sigmoid'),
    ([64, 32, 16], 'tanh')
]

for neurons, activation in architectures:
    print(f"Testing architecture: {neurons} with activation {activation}")
    train_acc, test_acc = build_model(hidden_neurons=neurons, activation=activation)
    print(f"Test Accuracy: {test_acc:.4f}\n")

    if test_acc > best_accuracy:
        best_accuracy = test_acc
        best_config = (neurons, activation)

print(f"Best Architecture: {best_config} with Accuracy: {best_accuracy:.4f}")
# Out:
# x_train shape: (60000, 28, 28)
# y_train shape: (60000,)
# x_test shape: (10000, 28, 28)
# y_test shape: (10000,)
# Epoch 1/10
# 469/469 - 32s - 68ms/step - accuracy: 0.1269 - loss: 2.2941 - val_accuracy: 0.1327 - val_loss: 2.2865
# Epoch 2/10
# 469/469 - 31s - 66ms/step - accuracy: 0.1362 - loss: 2.2818 - val_accuracy: 0.1412 - val_loss: 2.2745
# Epoch 3/10
# 469/469 - 31s - 66ms/step - accuracy: 0.1452 - loss: 2.2705 - val_accuracy: 0.1490 - val_loss: 2.2630
# Epoch 4/10
# 469/469 - 41s - 87ms/step - accuracy: 0.1538 - loss: 2.2594 - val_accuracy: 0.1614 - val_loss: 2.2516
# Epoch 5/10
# 469/469 - 31s - 67ms/step - accuracy: 0.1630 - loss: 2.2483 - val_accuracy: 0.1707 - val_loss: 2.2401
# Epoch 6/10
# 469/469 - 31s - 67ms/step - accuracy: 0.1734 - loss: 2.2369 - val_accuracy: 0.1812 - val_loss: 2.2283
# Epoch 7/10
# 469/469 - 40s - 86ms/step - accuracy: 0.1855 - loss: 2.2250 - val_accuracy: 0.1948 - val_loss: 2.2160
# Epoch 8/10
# 469/469 - 41s - 88ms/step - accuracy: 0.1979 - loss: 2.2128 - val_accuracy: 0.2106 - val_loss: 2.2034
# Epoch 9/10
# 469/469 - 30s - 65ms/step - accuracy: 0.2122 - loss: 2.2000 - val_accuracy: 0.2236 - val_loss: 2.1902
# Epoch 10/10
# 469/469 - 30s - 65ms/step - accuracy: 0.2247 - loss: 2.1868 - val_accuracy: 0.2345 - val_loss: 2.1767
# Training Accuracy: 0.2311
# Testing Accuracy: 0.2345
# Testing architecture: [64, 64, 64] with activation relu
# Epoch 1/10
# 469/469 - 31s - 66ms/step - accuracy: 0.1358 - loss: 2.2970 - val_accuracy: 0.1456 - val_loss: 2.2879
# Epoch 2/10
# 469/469 - 31s - 66ms/step - accuracy: 0.1628 - loss: 2.2785 - val_accuracy: 0.1774 - val_loss: 2.2685
# Epoch 3/10
# 469/469 - 42s - 90ms/step - accuracy: 0.1955 - loss: 2.2593 - val_accuracy: 0.2089 - val_loss: 2.2483
# Epoch 4/10
# 469/469 - 32s - 67ms/step - accuracy: 0.2266 - loss: 2.2394 - val_accuracy: 0.2385 - val_loss: 2.2274
# Epoch 5/10
# 469/469 - 32s - 69ms/step - accuracy: 0.2526 - loss: 2.2188 - val_accuracy: 0.2645 - val_loss: 2.2057
# Epoch 6/10
# 469/469 - 38s - 82ms/step - accuracy: 0.2755 - loss: 2.1971 - val_accuracy: 0.2901 - val_loss: 2.1827
# Epoch 7/10
# 469/469 - 33s - 70ms/step - accuracy: 0.2972 - loss: 2.1742 - val_accuracy: 0.3096 - val_loss: 2.1583
# Epoch 8/10
# 469/469 - 39s - 83ms/step - accuracy: 0.3173 - loss: 2.1496 - val_accuracy: 0.3309 - val_loss: 2.1322
# Epoch 9/10
# 469/469 - 42s - 89ms/step - accuracy: 0.3385 - loss: 2.1233 - val_accuracy: 0.3539 - val_loss: 2.1042
# Epoch 10/10
# 469/469 - 39s - 84ms/step - accuracy: 0.3602 - loss: 2.0950 - val_accuracy: 0.3744 - val_loss: 2.0742
# Test Accuracy: 0.3744
#
# Testing architecture: [128, 64, 32] with activation relu
# Epoch 1/10
# 469/469 - 31s - 67ms/step - accuracy: 0.1364 - loss: 2.3042 - val_accuracy: 0.1347 - val_loss: 2.2899
# Epoch 2/10
# 469/469 - 33s - 71ms/step - accuracy: 0.1510 - loss: 2.2713 - val_accuracy: 0.1526 - val_loss: 2.2558
# Epoch 3/10
# 469/469 - 40s - 85ms/step - accuracy: 0.1712 - loss: 2.2388 - val_accuracy: 0.1782 - val_loss: 2.2219
# Epoch 4/10
# 469/469 - 41s - 87ms/step - accuracy: 0.1982 - loss: 2.2057 - val_accuracy: 0.2097 - val_loss: 2.1872
# Epoch 5/10
# 469/469 - 32s - 69ms/step - accuracy: 0.2304 - loss: 2.1717 - val_accuracy: 0.2469 - val_loss: 2.1521
# Epoch 6/10
# 469/469 - 33s - 71ms/step - accuracy: 0.2662 - loss: 2.1373 - val_accuracy: 0.2825 - val_loss: 2.1169
# Epoch 7/10
# 469/469 - 33s - 70ms/step - accuracy: 0.3018 - loss: 2.1027 - val_accuracy: 0.3175 - val_loss: 2.0816
# Epoch 8/10
# 469/469 - 33s - 71ms/step - accuracy: 0.3356 - loss: 2.0678 - val_accuracy: 0.3540 - val_loss: 2.0459
# Epoch 9/10
# 469/469 - 40s - 86ms/step - accuracy: 0.3674 - loss: 2.0325 - val_accuracy: 0.3841 - val_loss: 2.0096
# Epoch 10/10
# 469/469 - 32s - 69ms/step - accuracy: 0.3959 - loss: 1.9968 - val_accuracy: 0.4117 - val_loss: 1.9729
# Test Accuracy: 0.4117
#
# Testing architecture: [32, 32, 32] with activation sigmoid
# Epoch 1/10
# 469/469 - 31s - 66ms/step - accuracy: 0.0904 - loss: 2.4279 - val_accuracy: 0.0892 - val_loss: 2.4304
# Epoch 2/10
# 469/469 - 30s - 65ms/step - accuracy: 0.0904 - loss: 2.4206 - val_accuracy: 0.0892 - val_loss: 2.4229
# Epoch 3/10
# 469/469 - 41s - 87ms/step - accuracy: 0.0904 - loss: 2.4132 - val_accuracy: 0.0892 - val_loss: 2.4154
# Epoch 4/10
# 469/469 - 30s - 64ms/step - accuracy: 0.0904 - loss: 2.4060 - val_accuracy: 0.0892 - val_loss: 2.4081
# Epoch 5/10
# 469/469 - 42s - 89ms/step - accuracy: 0.0904 - loss: 2.3991 - val_accuracy: 0.0892 - val_loss: 2.4012
# Epoch 6/10
# 469/469 - 41s - 87ms/step - accuracy: 0.0904 - loss: 2.3925 - val_accuracy: 0.0892 - val_loss: 2.3946
# Epoch 7/10
# 469/469 - 42s - 89ms/step - accuracy: 0.0904 - loss: 2.3862 - val_accuracy: 0.0892 - val_loss: 2.3883
# Epoch 8/10
# 469/469 - 41s - 88ms/step - accuracy: 0.0904 - loss: 2.3804 - val_accuracy: 0.0892 - val_loss: 2.3825
# Epoch 9/10
# 469/469 - 40s - 85ms/step - accuracy: 0.0904 - loss: 2.3749 - val_accuracy: 0.0892 - val_loss: 2.3770
# Epoch 10/10
# 469/469 - 41s - 87ms/step - accuracy: 0.0904 - loss: 2.3697 - val_accuracy: 0.0892 - val_loss: 2.3718
# Test Accuracy: 0.0892
#
# Testing architecture: [64, 32, 16] with activation tanh
# Epoch 1/10
# 469/469 - 32s - 67ms/step - accuracy: 0.0925 - loss: 2.3648 - val_accuracy: 0.1098 - val_loss: 2.3353
# Epoch 2/10
# 469/469 - 31s - 67ms/step - accuracy: 0.1367 - loss: 2.2906 - val_accuracy: 0.1461 - val_loss: 2.2641
# Epoch 3/10
# 469/469 - 30s - 65ms/step - accuracy: 0.1789 - loss: 2.2236 - val_accuracy: 0.1879 - val_loss: 2.1990
# Epoch 4/10
# 469/469 - 31s - 66ms/step - accuracy: 0.2232 - loss: 2.1620 - val_accuracy: 0.2344 - val_loss: 2.1384
# Epoch 5/10
# 469/469 - 30s - 64ms/step - accuracy: 0.2668 - loss: 2.1047 - val_accuracy: 0.2843 - val_loss: 2.0816
# Epoch 6/10
# 469/469 - 42s - 90ms/step - accuracy: 0.3136 - loss: 2.0510 - val_accuracy: 0.3352 - val_loss: 2.0286
# Epoch 7/10
# 469/469 - 30s - 64ms/step - accuracy: 0.3619 - loss: 2.0012 - val_accuracy: 0.3877 - val_loss: 1.9792
# Epoch 8/10
# 469/469 - 31s - 66ms/step - accuracy: 0.4055 - loss: 1.9547 - val_accuracy: 0.4310 - val_loss: 1.9332
# Epoch 9/10
# 469/469 - 42s - 89ms/step - accuracy: 0.4464 - loss: 1.9113 - val_accuracy: 0.4681 - val_loss: 1.8900
# Epoch 10/10
# 469/469 - 41s - 87ms/step - accuracy: 0.4823 - loss: 1.8707 - val_accuracy: 0.5049 - val_loss: 1.8497
# Test Accuracy: 0.5049
#
# Best Architecture: ([64, 32, 16], 'tanh') with Accuracy: 0.5049
